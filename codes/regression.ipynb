# %% [markdown]
# # Ploting linear regression line

# %%
#importing packages
# %matplotlib inline
import xlrd
import matplotlib
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
import seaborn as sns; sns.set()
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# after creating .csv file, we can obtain data from file directly
sc= pd.read_csv("../data/sc_final.csv")

# %%
sc.RPY_1YR_RT=pd.Series(sc.RPY_1YR_RT).convert_objects(convert_numeric=True)
sc.Year=sc.Year.astype('object')

print ("--------------------------1 years---------------------------------------")
rt1m=sns.lmplot(x="Year", y="RPY_1YR_RT", data=sc, fit_reg=True, scatter_kws={"marker": "D", 
                        "s": 100})
rt1m.set(xlabel='Year',ylabel='1 Year Repayment Rate',title='scatterplot of 1 Year Repayment Rate')
plt.show()
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# --------------------------1 years---------------------------------------

# %%
sc.RPY_3YR_RT=pd.Series(sc.RPY_3YR_RT).convert_objects(convert_numeric=True)
sc.Year=sc.Year.astype('object')


print ("--------------------------3 years---------------------------------------")
rt3m=sns.lmplot(x="Year", y="RPY_3YR_RT", data=sc, fit_reg=True, scatter_kws={"marker": "D", 
                        "s": 100})
rt3m.set(xlabel='Year',ylabel='3 Year Repayment Rate',title='scatterplot of 3 Year Repayment Rate')
plt.show()
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# --------------------------3 years---------------------------------------

# %%
sc.RPY_5YR_RT=pd.Series(sc.RPY_5YR_RT).convert_objects(convert_numeric=True)
sc.Year=sc.Year.astype('object')


print ("--------------------------5 years---------------------------------------")
rt5m=sns.lmplot(x="Year", y="RPY_5YR_RT", data=sc, fit_reg=True, scatter_kws={"marker": "D", 
                        "s": 100})
rt5m.set(xlabel='Year',ylabel='5 Year Repayment Rate',title='scatterplot of 5 Year Repayment Rate')
plt.show()
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# --------------------------5 years---------------------------------------

# %%
sc.RPY_7YR_RT=pd.Series(sc.RPY_7YR_RT).convert_objects(convert_numeric=True)
sc.Year=sc.Year.astype('object')


print ("--------------------------7 years---------------------------------------")
rt7m=sns.lmplot(x="Year", y="RPY_7YR_RT", data=sc, fit_reg=True, scatter_kws={"marker": "D", 
                        "s": 100})
rt7m.set(xlabel='Year',ylabel='7 Year Repayment Rate',title='scatterplot of 7 Year Repayment Rate')
plt.show()
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# --------------------------7 years---------------------------------------
#    Unnamed: 0  RPY_1YR_RT  RPY_3YR_RT  RPY_5YR_RT  RPY_7YR_RT  UNITID  \
# 0           0    0.477044         NaN         NaN         NaN  100654
# 1           1    0.608185         NaN         NaN         NaN  100663
# 2           2    0.657534         NaN         NaN         NaN  100690
# 3           3    0.657205         NaN         NaN         NaN  100706
# 4           4    0.432048         NaN         NaN         NaN  100724
#
#      OPEID  OPEID6                               INSTNM        CITY  ...   \
# 0   100200    1002             Alabama A & M University      Normal  ...
# 1   105200    1052  University of Alabama at Birmingham  Birmingham  ...
# ...
